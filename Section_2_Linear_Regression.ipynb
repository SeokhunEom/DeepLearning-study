# %% [markdown]
# <a href="https://colab.research.google.com/github/SeokhunEom/DeepLearning-study/blob/main/Section_2_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # Importing numpy for numerical operations
import tensorflow as tf  # Importing TensorFlow for building and training the model

# %%
# Training data
x_train = [1, 2, 3, 4]  # Input values
y_train = [0, -1, -2, -3]  # Corresponding output values (targets)

# %%
# Create a Sequential model in TensorFlow Keras
tf.model = tf.keras.Sequential()

# %%
# Add a dense (fully connected) layer to the model
# units=1 indicates the layer has one neuron (output dimension)
# input_dim=1 indicates the input dimension is one (each input is a single scalar value)
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1))

# %%
# Set up the optimizer
# SGD (Stochastic Gradient Descent) is the optimization algorithm
# lr=0.1 sets the learning rate for the optimizer
sgd = tf.keras.optimizers.SGD(learning_rate=0.1)

# %%
# Compile the model
# loss='mse' indicates mean squared error will be used as the loss function
# optimizer=sgd specifies that the optimizer for training the model is SGD
tf.model.compile(loss='mse', optimizer=sgd)

# %%
# Print a summary of the model's architecture
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
# fit() trains the model for a fixed number of epochs (iterations over the dataset)
# x_train and y_train are the training data
# epochs=200 means the model will be trained for 200 epochs
tf.model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 877ms/step - loss: 4.2455
# Epoch 2/200
# 1/1 [==============================] - 0s 23ms/step - loss: 2.0290
# Epoch 3/200
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0266
# Epoch 4/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5697
# Epoch 5/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3582
# Epoch 6/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2572
# Epoch 7/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2061
# Epoch 8/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1779
# Epoch 9/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1601
# Epoch 10/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1474
# Epoch 11/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1373
# Epoch 12/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1285
# Epoch 13/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1207
# Epoch 14/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1134
# Epoch 15/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1067
# Epoch 16/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1003
# Epoch 17/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0944
# Epoch 18/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0888
# Epoch 19/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0836
# Epoch 20/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0787
# Epoch 21/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0740
# Epoch 22/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0697
# Epoch 23/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0656
# Epoch 24/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0617
# Epoch 25/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0580
# Epoch 26/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0546
# Epoch 27/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0514
# Epoch 28/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0484
# Epoch 29/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0455
# Epoch 30/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0428
# Epoch 31/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0403
# Epoch 32/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0379
# Epoch 33/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0357
# Epoch 34/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0336
# Epoch 35/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0316
# Epoch 36/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0297
# Epoch 37/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0280
# Epoch 38/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0263
# Epoch 39/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0248
# Epoch 40/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0233
# Epoch 41/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0219
# Epoch 42/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0207
# Epoch 43/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0194
# Epoch 44/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0183
# Epoch 45/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0172
# Epoch 46/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0162
# Epoch 47/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0152
# Epoch 48/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0143
# Epoch 49/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0135
# Epoch 50/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0127
# Epoch 51/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0119
# Epoch 52/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0112
# Epoch 53/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0106
# Epoch 54/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0100
# Epoch 55/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0094
# Epoch 56/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0088
# Epoch 57/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0083
# Epoch 58/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0078
# Epoch 59/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0073
# Epoch 60/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 61/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0065
# Epoch 62/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0061
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0058
# Epoch 64/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0054
# Epoch 65/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0051
# Epoch 66/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0048
# Epoch 67/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0045
# Epoch 68/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0043
# Epoch 69/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0038
# Epoch 71/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 72/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033
# Epoch 73/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0031
# Epoch 74/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 75/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0028
# Epoch 76/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 77/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0025
# Epoch 78/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023
# Epoch 79/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 80/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 81/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0019
# Epoch 82/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 83/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 84/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0016
# Epoch 85/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0015
# Epoch 86/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 87/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 88/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 89/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 90/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0011
# Epoch 91/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0011
# Epoch 92/200
# 1/1 [==============================] - 0s 17ms/step - loss: 9.8821e-04
# Epoch 93/200
# 1/1 [==============================] - 0s 14ms/step - loss: 9.2992e-04
# Epoch 94/200
# 1/1 [==============================] - 0s 16ms/step - loss: 8.7507e-04
# Epoch 95/200
# 1/1 [==============================] - 0s 20ms/step - loss: 8.2346e-04
# Epoch 96/200
# 1/1 [==============================] - 0s 20ms/step - loss: 7.7489e-04
# Epoch 97/200
# 1/1 [==============================] - 0s 20ms/step - loss: 7.2918e-04
# Epoch 98/200
# 1/1 [==============================] - 0s 16ms/step - loss: 6.8617e-04
# Epoch 99/200
# 1/1 [==============================] - 0s 17ms/step - loss: 6.4570e-04
# Epoch 100/200
# 1/1 [==============================] - 0s 16ms/step - loss: 6.0762e-04
# Epoch 101/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.7178e-04
# Epoch 102/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3806e-04
# Epoch 103/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0632e-04
# Epoch 104/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7646e-04
# Epoch 105/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4836e-04
# Epoch 106/200
# 1/1 [==============================] - 0s 14ms/step - loss: 4.2191e-04
# Epoch 107/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.9702e-04
# Epoch 108/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.7361e-04
# Epoch 109/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5157e-04
# Epoch 110/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3084e-04
# Epoch 111/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1132e-04
# Epoch 112/200
# 1/1 [==============================] - 0s 19ms/step - loss: 2.9296e-04
# Epoch 113/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.7568e-04
# Epoch 114/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5942e-04
# Epoch 115/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4412e-04
# Epoch 116/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.2972e-04
# Epoch 117/200
# 1/1 [==============================] - 0s 20ms/step - loss: 2.1617e-04
# Epoch 118/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0342e-04
# Epoch 119/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.9142e-04
# Epoch 120/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8013e-04
# Epoch 121/200
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6951e-04
# Epoch 122/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5951e-04
# Epoch 123/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5010e-04
# Epoch 124/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4125e-04
# Epoch 125/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3292e-04
# Epoch 126/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2508e-04
# Epoch 127/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1770e-04
# Epoch 128/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1076e-04
# Epoch 129/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0423e-04
# Epoch 130/200
# 1/1 [==============================] - 0s 15ms/step - loss: 9.8077e-05
# Epoch 131/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.2293e-05
# Epoch 132/200
# 1/1 [==============================] - 0s 15ms/step - loss: 8.6849e-05
# Epoch 133/200
# 1/1 [==============================] - 0s 17ms/step - loss: 8.1726e-05
# Epoch 134/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.6905e-05
# Epoch 135/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.2370e-05
# Epoch 136/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8102e-05
# Epoch 137/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.4085e-05
# Epoch 138/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.0305e-05
# Epoch 139/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.6748e-05
# Epoch 140/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3401e-05
# Epoch 141/200
# 1/1 [==============================] - 0s 14ms/step - loss: 5.0252e-05
# Epoch 142/200
# 1/1 [==============================] - 0s 17ms/step - loss: 4.7288e-05
# Epoch 143/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4498e-05
# Epoch 144/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1874e-05
# Epoch 145/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.9404e-05
# Epoch 146/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7080e-05
# Epoch 147/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4893e-05
# Epoch 148/200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.2835e-05
# Epoch 149/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.0898e-05
# Epoch 150/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.9076e-05
# Epoch 151/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7360e-05
# Epoch 152/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5747e-05
# Epoch 153/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4229e-05
# Epoch 154/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2799e-05
# Epoch 155/200
# 1/1 [==============================] - 0s 21ms/step - loss: 2.1455e-05
# Epoch 156/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0189e-05
# Epoch 157/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8998e-05
# Epoch 158/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7878e-05
# Epoch 159/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6823e-05
# Epoch 160/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5831e-05
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4898e-05
# Epoch 162/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4019e-05
# Epoch 163/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3192e-05
# Epoch 164/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2414e-05
# Epoch 165/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1682e-05
# Epoch 166/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0993e-05
# Epoch 167/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0344e-05
# Epoch 168/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.7342e-06
# Epoch 169/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.1600e-06
# Epoch 170/200
# 1/1 [==============================] - 0s 14ms/step - loss: 8.6197e-06
# Epoch 171/200
# 1/1 [==============================] - 0s 13ms/step - loss: 8.1112e-06
# Epoch 172/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.6326e-06
# Epoch 173/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1826e-06
# Epoch 174/200
# 1/1 [==============================] - 0s 13ms/step - loss: 6.7588e-06
# Epoch 175/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.3604e-06
# Epoch 176/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.9850e-06
# Epoch 177/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.6321e-06
# Epoch 178/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.2998e-06
# Epoch 179/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.9874e-06
# Epoch 180/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6931e-06
# Epoch 181/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4164e-06
# Epoch 182/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1557e-06
# Epoch 183/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9107e-06
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6799e-06
# Epoch 185/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4630e-06
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2588e-06
# Epoch 187/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0666e-06
# Epoch 188/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8856e-06
# Epoch 189/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7156e-06
# Epoch 190/200
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5554e-06
# Epoch 191/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4046e-06
# Epoch 192/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.2627e-06
# Epoch 193/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.1293e-06
# Epoch 194/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0037e-06
# Epoch 195/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.8855e-06
# Epoch 196/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7743e-06
# Epoch 197/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6696e-06
# Epoch 198/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5712e-06
# Epoch 199/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4786e-06
# Epoch 200/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3913e-06

# %%
# Use the trained model to make predictions
# predict() returns the predicted values for the given input
# np.array([5, 4]) is the new input data for which predictions are made
y_predict = tf.model.predict(np.array([5, 4]))
# Out:
# 1/1 [==============================] - 0s 79ms/step

# %%
# Print the predicted values
print(y_predict)
# Out:
# [[-3.9980383]
#  [-2.9989905]]

# %%
# Migrate from TensorFlow 1.x to TensorFlow 2 by ChatGPT
import tensorflow as tf
import numpy as np

# Define training data
x_train = np.array([1, 2, 3], dtype=np.float32)
y_train = np.array([1, 2, 3], dtype=np.float32)

# Define the model using a TensorFlow Module
class LinearModel(tf.Module):
    def __init__(self):
        # Initialize model parameters (weights and bias)
        self.W = tf.Variable(tf.random.normal([1]), name='weight')
        self.b = tf.Variable(tf.random.normal([1]), name='bias')

    def __call__(self, x):
        # Define the model's forward pass
        return x * self.W + self.b

# Instantiate the model
model = LinearModel()

# Define the cost (loss) function
def compute_loss(y_pred, y_true):
    # Use mean squared error as the loss function
    return tf.reduce_mean(tf.square(y_pred - y_true))

# Define the optimizer
optimizer = tf.optimizers.SGD(learning_rate=0.01)

# Define a single training step using tf.function for performance optimization
@tf.function
def train_step(model, x, y):
    # Record the operations for automatic differentiation
    with tf.GradientTape() as tape:
        # Forward pass: compute predicted y
        y_pred = model(x)
        # Compute the loss
        loss = compute_loss(y_pred, y)
    # Compute the gradients of the loss with respect to the model's parameters
    gradients = tape.gradient(loss, [model.W, model.b])
    # Apply the gradients to the optimizer to minimize the loss
    optimizer.apply_gradients(zip(gradients, [model.W, model.b]))
    return loss

# Training loop
for step in range(2001):
    # Perform a single training step
    loss = train_step(model, x_train, y_train)
    # Print the loss and the current values of W and b every 200 steps
    if step % 200 == 0:
        print(f"Step {step}: Loss: {loss.numpy()}, W: {model.W.numpy()}, b: {model.b.numpy()}")
# Out:
# Step 0: Loss: 0.4585822522640228, W: [1.5672755], b: [-0.7251201]
# Step 200: Loss: 0.03670777752995491, W: [1.221988], b: [-0.50463104]
# Step 400: Loss: 0.014016776345670223, W: [1.137175], b: [-0.31183097]
# Step 600: Loss: 0.005352301988750696, W: [1.0847659], b: [-0.19269276]
# Step 800: Loss: 0.002043776446953416, W: [1.0523802], b: [-0.11907257]
# Step 1000: Loss: 0.0007804098422639072, W: [1.0323678], b: [-0.07357956]
# Step 1200: Loss: 0.000298003462376073, W: [1.0200016], b: [-0.04546796]
# Step 1400: Loss: 0.00011379141506040469, W: [1.0123596], b: [-0.02809629]
# Step 1600: Loss: 4.345076740719378e-05, W: [1.0076375], b: [-0.01736174]
# Step 1800: Loss: 1.659180452406872e-05, W: [1.0047195], b: [-0.01072851]
# Step 2000: Loss: 6.336141723295441e-06, W: [1.0029165], b: [-0.00662982]
